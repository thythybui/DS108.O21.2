# %% [markdown]
# BÀI THỰC HÀNH 4: THU THẬP VÀ TIỀN XỬ LÝ DỮ LIỆU TỔNG HỢP.
#
# Bộ dữ liệu: Human Activity Recognition Using Smartphones Data Set
#
# Link dữ liệu: https://d396qusza40orc.cloudfront.net/getdata%2Fprojectfiles%2FUCI HAR Dataset.zip

# %% [markdown]
# 2) Đọc file README.md và cho biết các thông tin sau:

# %% [markdown]
# a) Chức năng (nội dung) của bộ dữ liệu là gì?

# %% [markdown]
# Bộ dữ liệu Human Activity Recognition Using Smartphones được dùng để nhận dạng hoạt động của con người dựa trên dữ liệu cảm biến thu thập từ điện thoại thông minh (Samsung Galaxy S II). Các hoạt động gồm:
#
# Đi bộ
#
# Đi lên cầu thang
#
# Đi xuống cầu thang
#
# Ngồi
#
# Đứng
#
# Nằm
#
# Mục tiêu là xây dựng mô hình máy học có thể phân loại hoạt động của người dùng dựa trên tín hiệu từ gia tốc kế và con quay hồi chuyển.

# %% [markdown]
# b) Các tác giả của bộ dữ liệu?

# %% [markdown]
# Các tác giả gồm:
#
# Jorge L. Reyes-Ortiz
#
# Davide Anguita
#
# Alessandro Ghio
#
# Luca Oneto
#
# Thuộc phòng thí nghiệm Smartlab - Non Linear Complex Systems Laboratory, Đại học Genoa, Ý.

# %% [markdown]
# c) Cấu trúc các tập tin của bộ dữ liệu? Ý nghĩa từng tập tin.

# %% [markdown]
# Cấu trúc thư mục gồm các tập tin chính sau:
#
# README.txt: Giới thiệu tổng quát bộ dữ liệu.
#
# features_info.txt: Mô tả chi tiết về các biến đặc trưng (features).
#
# features.txt: Danh sách tên của tất cả 561 đặc trưng.
#
# activity_labels.txt: Ánh xạ giữa nhãn (số) và tên hoạt động (vd: 1 → WALKING).
#
# Thư mục train/ và test/:
#
# X_train.txt / X_test.txt: Ma trận đặc trưng của tập huấn luyện / kiểm tra (mỗi hàng tương ứng 1 mẫu với 561 đặc trưng).
#
# y_train.txt / y_test.txt: Nhãn tương ứng cho mỗi mẫu trong X_train / X_test.
#
# subject_train.txt / subject_test.txt: ID người thực hiện hoạt động trong từng mẫu.
#
# Thư mục con Inertial Signals/:
# Lưu tín hiệu thô theo từng trục (X, Y, Z) cho mỗi loại dữ liệu:
#
# total_acc_[x|y|z]_train.txt: Gia tốc toàn phần.
#
# body_acc_[x|y|z]_train.txt: Gia tốc phần thân (sau khi loại bỏ trọng lực).
#
# body_gyro_[x|y|z]_train.txt: Vận tốc góc (từ con quay hồi chuyển).

# %% [markdown]
# d) Các thông tin nào mà các record lưu trữ?

# %% [markdown]
# Mỗi record (dòng dữ liệu) lưu trữ các thông tin sau:
#
# Gia tốc theo 3 trục từ cảm biến gia tốc (cả tổng và phần thân).
#
# Vận tốc góc theo 3 trục từ con quay hồi chuyển.
#
# Vector đặc trưng gồm 561 biến trích xuất từ miền thời gian và tần số.
#
# Nhãn hoạt động (vd: đi bộ, ngồi...).
#
# ID người dùng thực hiện hoạt động đó.

# %% [markdown]
# 1) Tải dữ liệu về và đọc dữ liệu.

# %%
import pandas as pd

# %%
X_train = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/test/X_test.txt', delim_whitespace=True, header=None)
print(X_train.shape)
print(X_train.head())
# Out:
# C:\Users\Thy\AppData\Local\Temp\ipykernel_17800\760057441.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   X_train = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/test/X_test.txt', delim_whitespace=True, header=None)
# (2947, 561)
#         0         1         2         3         4         5         6    \
# 0  0.257178 -0.023285 -0.014654 -0.938404 -0.920091 -0.667683 -0.952501
# 1  0.286027 -0.013163 -0.119083 -0.975415 -0.967458 -0.944958 -0.986799
# 2  0.275485 -0.026050 -0.118152 -0.993819 -0.969926 -0.962748 -0.994403
# 3  0.270298 -0.032614 -0.117520 -0.994743 -0.973268 -0.967091 -0.995274
# 4  0.274833 -0.027848 -0.129527 -0.993852 -0.967445 -0.978295 -0.994111
#
#         7         8         9    ...       551       552       553       554  \
# 0 -0.925249 -0.674302 -0.894088  ...  0.071645 -0.330370 -0.705974  0.006462
# ...

# %%
Y_train = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/test/Y_test.txt', delim_whitespace=True, header=None)
print(Y_train.shape)
print(Y_train.head())
# Out:
# (2947, 1)
#    0
# 0  5
# 1  5
# 2  5
# 3  5
# 4  5
# C:\Users\Thy\AppData\Local\Temp\ipykernel_17800\561466115.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   Y_train = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/test/Y_test.txt', delim_whitespace=True, header=None)

# %%
subject_train = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/test/subject_test.txt', delim_whitespace=True, header=None)
print(subject_train.shape)
print(subject_train.head())
# Out:
# (2947, 1)
#    0
# 0  2
# 1  2
# 2  2
# 3  2
# 4  2
# C:\Users\Thy\AppData\Local\Temp\ipykernel_17800\3115364274.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   subject_train = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/test/subject_test.txt', delim_whitespace=True, header=None)

# %%
X_test = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/test/X_test.txt', delim_whitespace=True, header=None) 
print(X_test.shape)
print(X_test.head())
# Out:
# C:\Users\Thy\AppData\Local\Temp\ipykernel_17800\420344013.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   X_test = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/test/X_test.txt', delim_whitespace=True, header=None)
# (2947, 561)
#         0         1         2         3         4         5         6    \
# 0  0.257178 -0.023285 -0.014654 -0.938404 -0.920091 -0.667683 -0.952501
# 1  0.286027 -0.013163 -0.119083 -0.975415 -0.967458 -0.944958 -0.986799
# 2  0.275485 -0.026050 -0.118152 -0.993819 -0.969926 -0.962748 -0.994403
# 3  0.270298 -0.032614 -0.117520 -0.994743 -0.973268 -0.967091 -0.995274
# 4  0.274833 -0.027848 -0.129527 -0.993852 -0.967445 -0.978295 -0.994111
#
#         7         8         9    ...       551       552       553       554  \
# 0 -0.925249 -0.674302 -0.894088  ...  0.071645 -0.330370 -0.705974  0.006462
# ...

# %%
Y_test = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/test/Y_test.txt', delim_whitespace=True, header=None)
print(Y_test.shape)
print(Y_test.head())
# Out:
# (2947, 1)
#    0
# 0  5
# 1  5
# 2  5
# 3  5
# 4  5
# C:\Users\Thy\AppData\Local\Temp\ipykernel_17800\1271163768.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   Y_test = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/test/Y_test.txt', delim_whitespace=True, header=None)

# %%
subject_test = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/test/subject_test.txt', delim_whitespace=True, header=None)
print(subject_test.shape)   
print(subject_test.head())
# Out:
# (2947, 1)
#    0
# 0  2
# 1  2
# 2  2
# 3  2
# 4  2
# C:\Users\Thy\AppData\Local\Temp\ipykernel_17800\432412101.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   subject_test = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/test/subject_test.txt', delim_whitespace=True, header=None)

# %%
features = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/features.txt', delim_whitespace=True, header=None)
print(features.shape)
# Out:
# (561, 2)
# C:\Users\Thy\AppData\Local\Temp\ipykernel_17800\3058047365.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   features = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/features.txt', delim_whitespace=True, header=None)

# %%
features
# Out:
#        0                                     1
# 0      1                     tBodyAcc-mean()-X
# 1      2                     tBodyAcc-mean()-Y
# 2      3                     tBodyAcc-mean()-Z
# 3      4                      tBodyAcc-std()-X
# 4      5                      tBodyAcc-std()-Y
# ..   ...                                   ...
# 556  557      angle(tBodyGyroMean,gravityMean)
# 557  558  angle(tBodyGyroJerkMean,gravityMean)
# 558  559                  angle(X,gravityMean)
# 559  560                  angle(Y,gravityMean)
# 560  561                  angle(Z,gravityMean)
#
# [561 rows x 2 columns]

# %% [markdown]
# - Đọc dữ liệu từ file featrues.txt. Lấy cột tên các thuộc tính ra. (Sử dụng toán tử $ để lấy được dữ liệu dạng vector). Tổng cộng có 561 thuộc tính.
#
# - Gán tên thuộc tính lần lược cho X_train và X_test. Sử dụng hàm names().

# %%
X_train.columns = features[1].values
X_test.columns = features[1].values

# %%
X_train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.938404         -0.920091         -0.667683         -0.952501
# ...

# %%
X_test
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.938404         -0.920091         -0.667683         -0.952501
# ...

# %% [markdown]
# 3) Merge bộ dữ liệu train và test lại với nhau.

# %% [markdown]
# Merge dữ liệu:
# - Merge dữ liệu train: merge column giữa X_train, y_train và subject_train. Đặt tên biến là X_train_data.
# 	Sử dụng hàm cbind theo thứ tự: (y_train, subject_train, X_train).
# 	Đổi tên cột y_train thành "Activity", cột subject_train thành "Subject". Sử dụng hàm names(X_train_data)[1] <- "Activity ".
# - Merge dữ liệu test: merge column giữa X_test, y_test và subject_test. Đặt tên biến là X_test_data
# 	Thực hiện tương tự như merge dữ liệu train.

# %%
X_train_data = pd.concat([Y_train, subject_train, X_train], axis=1)

# %%
print(X_train_data.shape)
print(X_train_data.head())
# Out:
# (2947, 563)
#    0  0  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0  5  2           0.257178          -0.023285          -0.014654
# 1  5  2           0.286027          -0.013163          -0.119083
# 2  5  2           0.275485          -0.026050          -0.118152
# 3  5  2           0.270298          -0.032614          -0.117520
# 4  5  2           0.274833          -0.027848          -0.129527
#
#    tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0         -0.938404         -0.920091         -0.667683         -0.952501
# 1         -0.975415         -0.967458         -0.944958         -0.986799
# 2         -0.993819         -0.969926         -0.962748         -0.994403
# 3         -0.994743         -0.973268         -0.967091         -0.995274
# 4         -0.993852         -0.967445         -0.978295         -0.994111
#
#    tBodyAcc-mad()-Y  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# ...

# %%
X_train_data.columns = ['Activity', 'Subject'] + list(X_train_data.columns[2:])
X_train_data.head()
# Out:
#    Activity  Subject  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0         5        2           0.257178          -0.023285          -0.014654
# 1         5        2           0.286027          -0.013163          -0.119083
# 2         5        2           0.275485          -0.026050          -0.118152
# 3         5        2           0.270298          -0.032614          -0.117520
# 4         5        2           0.274833          -0.027848          -0.129527
#
#    tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0         -0.938404         -0.920091         -0.667683         -0.952501
# 1         -0.975415         -0.967458         -0.944958         -0.986799
# 2         -0.993819         -0.969926         -0.962748         -0.994403
# 3         -0.994743         -0.973268         -0.967091         -0.995274
# 4         -0.993852         -0.967445         -0.978295         -0.994111
#
# ...

# %%
X_test_data = pd.concat([Y_test, subject_test, X_test], axis=1)
print(X_test_data.shape)
# Out:
# (2947, 563)

# %%
X_test_data.columns = ['Activity', 'Subject'] + list(X_test_data.columns[2:])
X_test_data.head()
# Out:
#    Activity  Subject  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0         5        2           0.257178          -0.023285          -0.014654
# 1         5        2           0.286027          -0.013163          -0.119083
# 2         5        2           0.275485          -0.026050          -0.118152
# 3         5        2           0.270298          -0.032614          -0.117520
# 4         5        2           0.274833          -0.027848          -0.129527
#
#    tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0         -0.938404         -0.920091         -0.667683         -0.952501
# 1         -0.975415         -0.967458         -0.944958         -0.986799
# 2         -0.993819         -0.969926         -0.962748         -0.994403
# 3         -0.994743         -0.973268         -0.967091         -0.995274
# 4         -0.993852         -0.967445         -0.978295         -0.994111
#
# ...

# %% [markdown]
# - Merge dữ liệu giữa tập train và test lại với nhau.
# 	Sử dụng hàm rbind - gộp dòng. Gộp dữ liệu giữa 2 bộ X_train_data và X_test_data lại với nhau.

# %%
X_data = pd.concat([X_train_data, X_test_data], axis=0)
X_data
# Out:
#       Activity  Subject  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  \
# 0            5        2           0.257178          -0.023285
# 1            5        2           0.286027          -0.013163
# 2            5        2           0.275485          -0.026050
# 3            5        2           0.270298          -0.032614
# 4            5        2           0.274833          -0.027848
# ...        ...      ...                ...                ...
# 2942         2       24           0.310155          -0.053391
# 2943         2       24           0.363385          -0.039214
# 2944         2       24           0.349966           0.030077
# 2945         2       24           0.237594           0.018467
# 2946         2       24           0.153627          -0.018437
#
#       tBodyAcc-mean()-Z  tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# 0             -0.014654         -0.938404         -0.920091         -0.667683
# ...

# %% [markdown]
# 4) Với các thuộc tính dữ liệu, chỉ lấy ra các thuộc tính giá trị trung bình (mean) và giá trị độ lệch chuẩn (standard deviation).

# %% [markdown]
# Lấy thuộc tính mean và standard deviation ra.
# - Sử dụng lệnh colnames() để lấy danh sách tên cột của dữ liệu X_data ra.
# - Sử dụng lệnh grep() để tìm và trả về vị trí của các thuộc tính mà trong chuỗi tên có dạng mean và std. Pattern cho 2 chuỗi trên lần lượt là: "mean\\(\\)" và " std\\(\\)".
# - Chỉ lấy ra các cột (thuộc tính) có dạng mean và std như trên, kèm theo 2 thuộc tính vừa thêm vào là "Activity" và "Subject" ở Bước 4.
#
#     Lệnh ví dụ: X_mean_std <- X_data[,c(col_mean,col_std)].
#     col_mean là các vị trí của thuộc tính có chứa chuỗi mean, col_std là các vị trí của thuộc tính có chứa chuỗi std.
# - Sau khi lọc ra các thuộc tính có dạng mean và std, số thuộc tính (số cột) của bộ data sẽ giảm xuống nhỏ hơn 561.

# %%
X_data_columns = X_data.columns

# %%
import re

X_mean_std = X_data_columns[X_data_columns.str.contains('mean|std|Activity|Subject', regex=True)]
X_mean_std
# Out:
# Index(['Activity', 'Subject', 'tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y',
#        'tBodyAcc-mean()-Z', 'tBodyAcc-std()-X', 'tBodyAcc-std()-Y',
#        'tBodyAcc-std()-Z', 'tGravityAcc-mean()-X', 'tGravityAcc-mean()-Y',
#        'tGravityAcc-mean()-Z', 'tGravityAcc-std()-X', 'tGravityAcc-std()-Y',
#        'tGravityAcc-std()-Z', 'tBodyAccJerk-mean()-X', 'tBodyAccJerk-mean()-Y',
#        'tBodyAccJerk-mean()-Z', 'tBodyAccJerk-std()-X', 'tBodyAccJerk-std()-Y',
#        'tBodyAccJerk-std()-Z', 'tBodyGyro-mean()-X', 'tBodyGyro-mean()-Y',
#        'tBodyGyro-mean()-Z', 'tBodyGyro-std()-X', 'tBodyGyro-std()-Y',
#        'tBodyGyro-std()-Z', 'tBodyGyroJerk-mean()-X', 'tBodyGyroJerk-mean()-Y',
#        'tBodyGyroJerk-mean()-Z', 'tBodyGyroJerk-std()-X',
#        'tBodyGyroJerk-std()-Y', 'tBodyGyroJerk-std()-Z', 'tBodyAccMag-mean()',
#        'tBodyAccMag-std()', 'tGravityAccMag-mean()', 'tGravityAccMag-std()',
#        'tBodyAccJerkMag-mean()', 'tBodyAccJerkMag-std()',
# ...

# %%
X_mean_std = X_data[X_mean_std]
X_mean_std
# Out:
#       Activity  Subject  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  \
# 0            5        2           0.257178          -0.023285
# 1            5        2           0.286027          -0.013163
# 2            5        2           0.275485          -0.026050
# 3            5        2           0.270298          -0.032614
# 4            5        2           0.274833          -0.027848
# ...        ...      ...                ...                ...
# 2942         2       24           0.310155          -0.053391
# 2943         2       24           0.363385          -0.039214
# 2944         2       24           0.349966           0.030077
# 2945         2       24           0.237594           0.018467
# 2946         2       24           0.153627          -0.018437
#
#       tBodyAcc-mean()-Z  tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# 0             -0.014654         -0.938404         -0.920091         -0.667683
# ...

# %% [markdown]
# 5) Đặt tên header cho bộ dữ liệu sao cho tên có ý nghĩa.

# %%
rename_rules = {
    '^t': 'Time',
    '^f': 'Frequency',
    '-': ',',
    'mean\\(\\)': 'mean value',
    'std\\(\\)': 'standard deviation value',
    '-X': 'on X axis',
    '-Y': 'on Y axis',
    '-Z': 'on Z axis',
    'AccJerk': 'acceleration jerk',
    'Acc': 'Acceleration',
    'GyroJerk': 'angular velocity jerk',
    'Gyro': 'angular velocity',
    'Mag': 'Magnitude'
}

for pattern, replacement in rename_rules.items():
    X_mean_std.columns = X_mean_std.columns.str.replace(pattern, replacement, regex=True)

# %%
X_mean_std
# Out:
#       Activity  Subject  TimeBodyAcceleration,mean value,X  \
# 0            5        2                           0.257178
# 1            5        2                           0.286027
# 2            5        2                           0.275485
# 3            5        2                           0.270298
# 4            5        2                           0.274833
# ...        ...      ...                                ...
# 2942         2       24                           0.310155
# 2943         2       24                           0.363385
# 2944         2       24                           0.349966
# 2945         2       24                           0.237594
# 2946         2       24                           0.153627
#
#       TimeBodyAcceleration,mean value,Y  TimeBodyAcceleration,mean value,Z  \
# 0                             -0.023285                          -0.014654
# 1                             -0.013163                          -0.119083
# ...

# %% [markdown]
# Tính giá trị trung bình của từng giá trị các thuộc tính trong bộ dữ liệu theo 2 thuộc tính là Activity và Subject

# %%
X_mean_std = X_mean_std.groupby(['Subject', 'Activity']).mean().reset_index()
X_mean_std
# Out:
#     Subject  Activity  TimeBodyAcceleration,mean value,X  \
# 0         2         1                           0.276427
# 1         2         2                           0.247165
# 2         2         3                           0.277615
# 3         2         4                           0.277087
# 4         2         5                           0.277911
# 5         2         6                           0.281373
# 6         4         1                           0.278582
# 7         4         2                           0.270877
# 8         4         3                           0.279965
# 9         4         4                           0.271538
# 10        4         5                           0.280500
# 11        4         6                           0.263559
# 12        9         1                           0.278503
# 13        9         2                           0.262436
# 14        9         3                           0.295923
# ...

# %%
activity_labels = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/activity_labels.txt', delim_whitespace=True, header=None)
activity_labels
# Out:
# C:\Users\Thy\AppData\Local\Temp\ipykernel_17800\337957407.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   activity_labels = pd.read_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/activity_labels.txt', delim_whitespace=True, header=None)
#    0                   1
# 0  1             WALKING
# 1  2    WALKING_UPSTAIRS
# 2  3  WALKING_DOWNSTAIRS
# 3  4             SITTING
# 4  5            STANDING
# 5  6              LAYING

# %%
activity_labels.columns = ['Activity', 'Activity Name']
activity_labels_dictionary = dict(zip(activity_labels['Activity'], activity_labels['Activity Name']))
activity_labels_dictionary
# Out:
# {1: 'WALKING',
#  2: 'WALKING_UPSTAIRS',
#  3: 'WALKING_DOWNSTAIRS',
#  4: 'SITTING',
#  5: 'STANDING',
#  6: 'LAYING'}

# %%
X_mean_std['Activity'] = X_mean_std['Activity'].map(activity_labels_ditionary)
X_mean_std
# Out:
#     Subject            Activity  TimeBodyAcceleration,mean value,X  \
# 0         2             WALKING                           0.276427
# 1         2    WALKING_UPSTAIRS                           0.247165
# 2         2  WALKING_DOWNSTAIRS                           0.277615
# 3         2             SITTING                           0.277087
# 4         2            STANDING                           0.277911
# 5         2              LAYING                           0.281373
# 6         4             WALKING                           0.278582
# 7         4    WALKING_UPSTAIRS                           0.270877
# 8         4  WALKING_DOWNSTAIRS                           0.279965
# 9         4             SITTING                           0.271538
# 10        4            STANDING                           0.280500
# 11        4              LAYING                           0.263559
# 12        9             WALKING                           0.278503
# ...

# %%
X_mean_std.to_csv('D:/LAP TRINH/DS108.O21.2/LAB_3/UCI HAR Dataset/tidy_data.txt', index=False, sep='\t')
